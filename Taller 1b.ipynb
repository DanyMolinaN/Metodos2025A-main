# %%
import numpy as np
import matplotlib.pyplot as plt
from src.iterative_methods import gauss_jacobi  # Asegúrate de importar correctamente


def plot_trajectory(traj, label):
    traj_array = np.hstack(traj)  # De lista de (2,1) a matriz (2,N)
    x1 = traj_array[0, :]
    x2 = traj_array[1, :]
    plt.plot(x1, x2, marker='o', label=label)
    for i in range(len(x1)):
        plt.text(x1[i], x2[i], str(i), fontsize=7, ha='right')


# ================================
# Sistema 1: x1 + x2 = 7 ; -2x1 + 5x2 = 0
# ================================
A1 = np.array([[1, 1], [-2, 5]], dtype=float)
b1 = np.array([[7], [0]], dtype=float)
x0_list = [np.array([[0.0], [0.0]]), np.array([[5.0], [2.0]])]

plt.figure(figsize=(6, 6))
for x0 in x0_list:
    _, traj1 = gauss_jacobi(A=A1, b=b1, x0=x0, tol=1e-5, max_iter=50)
    plot_trajectory(traj1, label=f"Inicial: {x0.ravel().tolist()}")
plt.axhline(0, color='gray', lw=0.5)
plt.axvline(0, color='gray', lw=0.5)
plt.title("Sistema 1: x₁ + x₂ = 7, -2x₁ + 5x₂ = 0")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.tight_layout()
plt.show()


# ================================
# Sistema 2: x1 + x2 = 6 ; -2x1 + x2 = 0
# ================================
A2 = np.array([[1, 1], [-2, 1]], dtype=float)
b2 = np.array([[6], [0]], dtype=float)

plt.figure(figsize=(6, 6))
for x0 in x0_list:
    _, traj2 = gauss_jacobi(A=A2, b=b2, x0=x0, tol=1e-5, max_iter=50)
    plot_trajectory(traj2, label=f"Inicial: {x0.ravel().tolist()}")
plt.axhline(0, color='gray', lw=0.5)
plt.axvline(0, color='gray', lw=0.5)
plt.title("Sistema 2: x₁ + x₂ = 6, -2x₁ + x₂ = 0")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# [07-15 17:27:02][INFO] i= 0 x: [[0. 0.]]
# [07-15 17:27:02][INFO] i= 1 x: [[7. 0.]]
# [07-15 17:27:02][INFO] i= 2 x: [[7.  2.8]]
# [07-15 17:27:02][INFO] i= 3 x: [[4.2 2.8]]
# [07-15 17:27:02][INFO] i= 4 x: [[4.2  1.68]]
# [07-15 17:27:02][INFO] i= 5 x: [[5.32 1.68]]
# [07-15 17:27:02][INFO] i= 6 x: [[5.32  2.128]]
# [07-15 17:27:02][INFO] i= 7 x: [[4.872 2.128]]
# [07-15 17:27:02][INFO] i= 8 x: [[4.872  1.9488]]
# [07-15 17:27:02][INFO] i= 9 x: [[5.0512 1.9488]]
# [07-15 17:27:02][INFO] i= 10 x: [[5.0512  2.02048]]
# [07-15 17:27:02][INFO] i= 11 x: [[4.97952 2.02048]]
# [07-15 17:27:02][INFO] i= 12 x: [[4.97952  1.991808]]
# [07-15 17:27:02][INFO] i= 13 x: [[5.008192 1.991808]]
# [07-15 17:27:02][INFO] i= 14 x: [[5.008192  2.0032768]]
# [07-15 17:27:02][INFO] i= 20 x: [[ 3074. -2044.]]
# [07-15 17:27:02][INFO] i= 21 x: [[2050. 6148.]]
# [07-15 17:27:02][INFO] i= 22 x: [[-6142.  4100.]]
# [07-15 17:27:02][INFO] i= 23 x: [[ -4094. -12284.]]
# [07-15 17:27:02][INFO] i= 24 x: [[12290. -8188.]]
# [07-15 17:27:02][INFO] i= 25 x: [[ 8194. 24580.]]
# [07-15 17:27:02][INFO] i= 26 x: [[-24574.  16388.]]
# [07-15 17:27:02][INFO] i= 27 x: [[-16382. -49148.]]
# [07-15 17:27:02][INFO] i= 28 x: [[ 49154. -32764.]]
# [07-15 17:27:02][INFO] i= 29 x: [[32770. 98308.]]
# [07-15 17:27:02][INFO] i= 30 x: [[-98302.  65540.]]
# [07-15 17:27:02][INFO] i= 31 x: [[ -65534. -196604.]]
# [07-15 17:27:02][INFO] i= 32 x: [[ 196610. -131068.]]
# [07-15 17:27:02][INFO] i= 33 x: [[131074. 393220.]]
# [07-15 17:27:02][INFO] i= 34 x: [[-393214.  262148.]]
# [07-15 17:27:02][INFO] i= 35 x: [[-262142. -786428.]]
# [07-15 17:27:02][INFO] i= 36 x: [[ 786434. -524284.]]
# [07-15 17:27:02][INFO] i= 37 x: [[ 524290. 1572868.]]
# [07-15 17:27:02][INFO] i= 38 x: [[-1572862.  1048580.]]
# [07-15 17:27:02][INFO] i= 39 x: [[-1048574. -3145724.]]
# [07-15 17:27:02][INFO] i= 40 x: [[ 3145730. -2097148.]]
# [07-15 17:27:02][INFO] i= 41 x: [[2097154. 6291460.]]
# [07-15 17:27:02][INFO] i= 42 x: [[-6291454.  4194308.]]
# [07-15 17:27:02][INFO] i= 43 x: [[ -4194302. -12582908.]]
# [07-15 17:27:02][INFO] i= 44 x: [[12582914. -8388604.]]
# [07-15 17:27:02][INFO] i= 45 x: [[ 8388610. 25165828.]]
# [07-15 17:27:02][INFO] i= 46 x: [[-25165822.  16777220.]]
# [07-15 17:27:02][INFO] i= 47 x: [[-16777214. -50331644.]]
# [07-15 17:27:02][INFO] i= 48 x: [[ 50331650. -33554428.]]
# [07-15 17:27:02][INFO] i= 49 x: [[3.3554434e+07 1.0066330e+08]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.iterative_methods import gauss_jacobi  # Asegúrate de importar correctamente


def plot_trajectory(traj, label):
    traj_array = np.hstack(traj)  # De lista de (2,1) a matriz (2,N)
    x1 = traj_array[0, :]
    x2 = traj_array[1, :]
    plt.plot(x1, x2, marker='o', label=label)
    for i in range(len(x1)):
        plt.text(x1[i], x2[i], str(i), fontsize=7, ha='right')


# ================================
# Sistema 1: x1 + x2 = 7 ; -2x1 + 5x2 = 0
# ================================
A1 = np.array([[1, 1], [-2, 5]], dtype=float)
b1 = np.array([[7], [0]], dtype=float)
x0_list = [np.array([[0.0], [0.0]]), np.array([[5.0], [2.0]])]

plt.figure(figsize=(6, 6))
for x0 in x0_list:
    _, traj1 = gauss_seidel(A=A1, b=b1, x0=x0, tol=1e-5, max_iter=50)
    plot_trajectory(traj1, label=f"Inicial: {x0.ravel().tolist()}")
plt.axhline(0, color='gray', lw=0.5)
plt.axvline(0, color='gray', lw=0.5)
plt.title("Sistema 1: x₁ + x₂ = 7, -2x₁ + 5x₂ = 0")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.tight_layout()
plt.show()


# ================================
# Sistema 2: x1 + x2 = 6 ; -2x1 + x2 = 0
# ================================
A2 = np.array([[1, 1], [-2, 1]], dtype=float)
b2 = np.array([[6], [0]], dtype=float)

plt.figure(figsize=(6, 6))
for x0 in x0_list:
    _, traj2 = gauss_seidel(A=A2, b=b2, x0=x0, tol=1e-5, max_iter=50)
    plot_trajectory(traj2, label=f"Inicial: {x0.ravel().tolist()}")
plt.axhline(0, color='gray', lw=0.5)
plt.axvline(0, color='gray', lw=0.5)
plt.title("Sistema 2: x₁ + x₂ = 6, -2x₁ + x₂ = 0")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# [07-15 17:28:06][INFO] i= 0 x: [[0. 0.]]
# [07-15 17:28:06][INFO] i= 1 x: [[7.  2.8]]
# [07-15 17:28:06][INFO] i= 2 x: [[4.2  1.68]]
# [07-15 17:28:06][INFO] i= 3 x: [[5.32  2.128]]
# [07-15 17:28:06][INFO] i= 4 x: [[4.872  1.9488]]
# [07-15 17:28:06][INFO] i= 5 x: [[5.0512  2.02048]]
# [07-15 17:28:06][INFO] i= 6 x: [[4.97952  1.991808]]
# [07-15 17:28:06][INFO] i= 7 x: [[5.008192  2.0032768]]
# [07-15 17:28:06][INFO] i= 8 x: [[4.9967232  1.99868928]]
# [07-15 17:28:06][INFO] i= 9 x: [[5.00131072 2.00052429]]
# [07-15 17:28:06][INFO] i= 10 x: [[4.99947571 1.99979028]]
# [07-15 17:28:06][INFO] i= 11 x: [[5.00020972 2.00008389]]
# [07-15 17:28:06][INFO] i= 12 x: [[4.99991611 1.99996645]]
# [07-15 17:28:06][INFO] i= 13 x: [[5.00003355 2.00001342]]
# [07-15 17:28:06][INFO] i= 14 x: [[4.99998658 1.99999463]]
# [07-15 17:28:06][INFO] i= 15 x: [[5.00000537 2.00000215]]
# [07-15 17:28:06][INFO] i= 0 x: [[5. 2.]]
# [07-15 17:28:06][INFO] i= 0 x: [[0. 0.]]
# [07-15 17:28:06][INFO] i= 1 x: [[ 6. 12.]]
# [07-15 17:28:06][INFO] i= 2 x: [[ -6. -12.]]
# [07-15 17:28:06][INFO] i= 3 x: [[18. 36.]]
# [07-15 17:28:06][INFO] i= 4 x: [[-30. -60.]]
# [07-15 17:28:06][INFO] i= 5 x: [[ 66. 132.]]
# [07-15 17:28:06][INFO] i= 6 x: [[-126. -252.]]
# [07-15 17:28:06][INFO] i= 7 x: [[258. 516.]]
# [07-15 17:28:06][INFO] i= 8 x: [[ -510. -1020.]]
# [07-15 17:28:06][INFO] i= 9 x: [[1026. 2052.]]
# [07-15 17:28:06][INFO] i= 10 x: [[-2046. -4092.]]
# [07-15 17:28:06][INFO] i= 11 x: [[4098. 8196.]]
# [07-15 17:28:06][INFO] i= 12 x: [[ -8190. -16380.]]
# [07-15 17:28:06][INFO] i= 13 x: [[16386. 32772.]]
# [07-15 17:28:06][INFO] i= 14 x: [[-32766. -65532.]]
# [07-15 17:28:06][INFO] i= 15 x: [[ 65538. 131076.]]
# [07-15 17:28:06][INFO] i= 16 x: [[-131070. -262140.]]
# [07-15 17:28:06][INFO] i= 17 x: [[262146. 524292.]]
# [07-15 17:28:06][INFO] i= 18 x: [[ -524286. -1048572.]]
# [07-15 17:28:06][INFO] i= 19 x: [[1048578. 2097156.]]
# [07-15 17:28:06][INFO] i= 20 x: [[-2097150. -4194300.]]
# [07-15 17:28:06][INFO] i= 21 x: [[4194306. 8388612.]]
# [07-15 17:28:06][INFO] i= 22 x: [[ -8388606. -16777212.]]
# [07-15 17:28:06][INFO] i= 23 x: [[16777218. 33554436.]]
# [07-15 17:28:06][INFO] i= 24 x: [[-33554430. -67108860.]]
# [07-15 17:28:06][INFO] i= 25 x: [[6.71088660e+07 1.34217732e+08]]
# [07-15 17:28:06][INFO] i= 26 x: [[-1.34217726e+08 -2.68435452e+08]]
# [07-15 17:28:06][INFO] i= 27 x: [[2.68435458e+08 5.36870916e+08]]
# [07-15 17:28:06][INFO] i= 28 x: [[-5.36870910e+08 -1.07374182e+09]]
# [07-15 17:28:06][INFO] i= 29 x: [[1.07374183e+09 2.14748365e+09]]
# [07-15 17:28:06][INFO] i= 30 x: [[-2.14748365e+09 -4.29496729e+09]]
# [07-15 17:28:06][INFO] i= 31 x: [[4.2949673e+09 8.5899346e+09]]
# [07-15 17:28:06][INFO] i= 32 x: [[-8.58993459e+09 -1.71798692e+10]]
# [07-15 17:28:06][INFO] i= 33 x: [[1.71798692e+10 3.43597384e+10]]
# [07-15 17:28:06][INFO] i= 34 x: [[-3.43597384e+10 -6.87194767e+10]]
# [07-15 17:28:06][INFO] i= 35 x: [[6.87194767e+10 1.37438953e+11]]
# [07-15 17:28:06][INFO] i= 36 x: [[-1.37438953e+11 -2.74877907e+11]]
# [07-15 17:28:06][INFO] i= 37 x: [[2.74877907e+11 5.49755814e+11]]
# [07-15 17:28:06][INFO] i= 38 x: [[-5.49755814e+11 -1.09951163e+12]]
# [07-15 17:28:06][INFO] i= 39 x: [[1.09951163e+12 2.19902326e+12]]
# [07-15 17:28:06][INFO] i= 40 x: [[-2.19902326e+12 -4.39804651e+12]]
# [07-15 17:28:06][INFO] i= 41 x: [[4.39804651e+12 8.79609302e+12]]
# [07-15 17:28:06][INFO] i= 42 x: [[-8.79609302e+12 -1.75921860e+13]]
# [07-15 17:28:06][INFO] i= 43 x: [[1.75921860e+13 3.51843721e+13]]
# [07-15 17:28:06][INFO] i= 44 x: [[-3.51843721e+13 -7.03687442e+13]]
# [07-15 17:28:06][INFO] i= 45 x: [[7.03687442e+13 1.40737488e+14]]
# [07-15 17:28:06][INFO] i= 46 x: [[-1.40737488e+14 -2.81474977e+14]]
# [07-15 17:28:06][INFO] i= 36 x: [[-6.87194767e+10 -1.37438953e+11]]
# [07-15 17:28:06][INFO] i= 37 x: [[1.37438953e+11 2.74877907e+11]]
# [07-15 17:28:06][INFO] i= 38 x: [[-2.74877907e+11 -5.49755814e+11]]
# [07-15 17:28:06][INFO] i= 39 x: [[5.49755814e+11 1.09951163e+12]]
# [07-15 17:28:06][INFO] i= 40 x: [[-1.09951163e+12 -2.19902326e+12]]
# [07-15 17:28:06][INFO] i= 41 x: [[2.19902326e+12 4.39804651e+12]]
# [07-15 17:28:06][INFO] i= 42 x: [[-4.39804651e+12 -8.79609302e+12]]
# [07-15 17:28:06][INFO] i= 43 x: [[8.79609302e+12 1.75921860e+13]]
# [07-15 17:28:06][INFO] i= 44 x: [[-1.75921860e+13 -3.51843721e+13]]
# [07-15 17:28:06][INFO] i= 45 x: [[3.51843721e+13 7.03687442e+13]]
# [07-15 17:28:06][INFO] i= 46 x: [[-7.03687442e+13 -1.40737488e+14]]
# [07-15 17:28:06][INFO] i= 47 x: [[1.40737488e+14 2.81474977e+14]]
# [07-15 17:28:06][INFO] i= 48 x: [[-2.81474977e+14 -5.62949953e+14]]
# [07-15 17:28:06][INFO] i= 49 x: [[5.62949953e+14 1.12589991e+15]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.iterative_methods import gauss_jacobi


def plot_trajectory(traj, label):
    traj_array = np.hstack(traj)  # De lista de (2,1) a matriz (2,N)
    x1 = traj_array[0, :]
    x2 = traj_array[1, :]
    plt.plot(x1, x2, marker='o', label=label)
    for i in range(len(x1)):
        plt.text(x1[i], x2[i], str(i), fontsize=7, ha='right')


def es_divergente(trayectoria, umbral=1e3):
    """
    Verifica si alguna iteración supera el umbral dado.
    """
    return any(np.linalg.norm(x) > umbral for x in trayectoria)


# ================================
# Sistema 1: x1 + x2 = 7 ; -2x1 + 5x2 = 0
# ================================
A1 = np.array([[1, 1], [-2, 5]], dtype=float)
b1 = np.array([[7], [0]], dtype=float)
x0_list = [np.array([[0.0], [0.0]]), np.array([[5.0], [2.0]])]

plt.figure(figsize=(6, 6))
for x0 in x0_list:
    _, traj1 = gauss_jacobi(A=A1, b=b1, x0=x0, tol=1e-5, max_iter=50)
    if es_divergente(traj1):
        print(f"Divergencia detectada en Sistema 1 para x0 = {x0.ravel().tolist()}")
        continue
    plot_trajectory(traj1, label=f"Inicial: {x0.ravel().tolist()}")
plt.axhline(0, color='gray', lw=0.5)
plt.axvline(0, color='gray', lw=0.5)
plt.title("Sistema 1: x₁ + x₂ = 7, -2x₁ + 5x₂ = 0")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.tight_layout()
plt.show()


# ================================
# Sistema 2: x1 + x2 = 6 ; -2x1 + x2 = 0
# ================================
A2 = np.array([[1, 1], [-2, 1]], dtype=float)
b2 = np.array([[6], [0]], dtype=float)

plt.figure(figsize=(6, 6))
for x0 in x0_list:
    _, traj2 = gauss_jacobi(A=A2, b=b2, x0=x0, tol=1e-5, max_iter=50)
    if es_divergente(traj2):
        print(f"Divergencia detectada en Sistema 2 para x0 = {x0.ravel().tolist()}")
        continue
    plot_trajectory(traj2, label=f"Inicial: {x0.ravel().tolist()}")
plt.axhline(0, color='gray', lw=0.5)
plt.axvline(0, color='gray', lw=0.5)
plt.title("Sistema 2: x₁ + x₂ = 6, -2x₁ + x₂ = 0")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# [07-15 17:23:03][INFO] 2025-07-15 17:23:03.580230
# [07-15 17:23:03][INFO] 2025-07-15 17:23:03.581563
# [07-15 17:23:03][INFO] i= 0 x: [[0. 0.]]
# [07-15 17:23:03][INFO] i= 1 x: [[7. 0.]]
# [07-15 17:23:03][INFO] i= 2 x: [[7.  2.8]]
# [07-15 17:23:03][INFO] i= 3 x: [[4.2 2.8]]
# [07-15 17:23:03][INFO] i= 4 x: [[4.2  1.68]]
# [07-15 17:23:03][INFO] i= 5 x: [[5.32 1.68]]
# [07-15 17:23:03][INFO] i= 6 x: [[5.32  2.128]]
# [07-15 17:23:03][INFO] i= 7 x: [[4.872 2.128]]
# [07-15 17:23:03][INFO] i= 8 x: [[4.872  1.9488]]
# [07-15 17:23:03][INFO] i= 9 x: [[5.0512 1.9488]]
# [07-15 17:23:03][INFO] i= 10 x: [[5.0512  2.02048]]
# [07-15 17:23:03][INFO] i= 11 x: [[4.97952 2.02048]]
# [07-15 17:23:03][INFO] i= 12 x: [[4.97952  1.991808]]
# [07-15 17:23:03][INFO] i= 13 x: [[5.008192 1.991808]]
# [07-15 17:23:03][INFO] i= 14 x: [[5.008192  2.0032768]]
# [07-15 17:23:03][INFO] i= 15 x: [[4.9967232 2.0032768]]
# [07-15 17:23:03][INFO] i= 16 x: [[4.9967232  1.99868928]]
# [07-15 17:23:03][INFO] i= 17 x: [[5.00131072 1.99868928]]
# [07-15 17:23:03][INFO] i= 18 x: [[5.00131072 2.00052429]]
# [07-15 17:23:03][INFO] i= 19 x: [[4.99947571 2.00052429]]
# [07-15 17:23:03][INFO] i= 20 x: [[4.99947571 1.99979028]]
# [07-15 17:23:03][INFO] i= 21 x: [[5.00020972 1.99979028]]
# [07-15 17:23:03][INFO] i= 22 x: [[5.00020972 2.00008389]]
# [07-15 17:23:03][INFO] i= 23 x: [[4.99991611 2.00008389]]
# [07-15 17:23:03][INFO] i= 24 x: [[4.99991611 1.99996645]]
# [07-15 17:23:03][INFO] i= 25 x: [[5.00003355 1.99996645]]
# [07-15 17:23:03][INFO] i= 26 x: [[5.00003355 2.00001342]]
# [07-15 17:23:03][INFO] i= 27 x: [[4.99998658 2.00001342]]
# [07-15 17:23:03][INFO] i= 28 x: [[4.99998658 1.99999463]]
# [07-15 17:23:03][INFO] i= 29 x: [[5.00000537 1.99999463]]
# [07-15 17:23:03][INFO] i= 0 x: [[5. 2.]]
# [07-15 17:23:03][INFO] i= 0 x: [[0. 0.]]
# [07-15 17:23:03][INFO] i= 1 x: [[6. 0.]]
# [07-15 17:23:03][INFO] i= 37 x: [[ 524290. 1572868.]]
# [07-15 17:23:03][INFO] i= 38 x: [[-1572862.  1048580.]]
# [07-15 17:23:03][INFO] i= 39 x: [[-1048574. -3145724.]]
# [07-15 17:23:03][INFO] i= 40 x: [[ 3145730. -2097148.]]
# [07-15 17:23:03][INFO] i= 41 x: [[2097154. 6291460.]]
# [07-15 17:23:03][INFO] i= 42 x: [[-6291454.  4194308.]]
# [07-15 17:23:03][INFO] i= 43 x: [[ -4194302. -12582908.]]
# [07-15 17:23:03][INFO] i= 44 x: [[12582914. -8388604.]]
# [07-15 17:23:03][INFO] i= 45 x: [[ 8388610. 25165828.]]
# [07-15 17:23:03][INFO] i= 46 x: [[-25165822.  16777220.]]
# [07-15 17:23:03][INFO] i= 47 x: [[-16777214. -50331644.]]
# [07-15 17:23:03][INFO] i= 48 x: [[ 50331650. -33554428.]]
# [07-15 17:23:03][INFO] i= 49 x: [[3.3554434e+07 1.0066330e+08]]
# Divergencia detectada en Sistema 2 para x0 = [5.0, 2.0]
# C:\Users\P3E009-E\AppData\Local\Temp\ipykernel_14240\2515054029.py:66: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from src.iterative_methods import gauss_jacobi  # Tu implementación original, sin modificar


def plot_system(ax, A, b, xlim=(-10, 10), ylim=(-10, 10)):
    """Dibuja las rectas del sistema de ecuaciones 2x2 en el plano"""
    x_vals = np.linspace(xlim[0], xlim[1], 400)

    for i in range(2):
        if A[i, 1] != 0:
            # x2 = (b - a11*x1)/a12
            y_vals = (b[i] - A[i, 0] * x_vals) / A[i, 1]
            ax.plot(x_vals, y_vals, label=f"Ecuación {i+1}")
        else:
            # x1 = b / a11
            x_const = b[i] / A[i, 0]
            ax.axvline(x_const, label=f"Ecuación {i+1}", linestyle='--')


def animate_jacobi(ax, traj, label):
    """Crea la animación de la trayectoria"""
    traj_array = np.hstack(traj)
    x1_vals = traj_array[0, :]
    x2_vals = traj_array[1, :]

    line, = ax.plot([], [], 'o-', label=label)
    texts = []

    def init():
        line.set_data([], [])
        return line,

    def update(frame):
        line.set_data(x1_vals[:frame+1], x2_vals[:frame+1])
        for txt in texts:
            txt.remove()
        texts.clear()
        for i in range(frame+1):
            txt = ax.text(x1_vals[i], x2_vals[i], str(i), fontsize=7, ha='right')
            texts.append(txt)
        return line, *texts

    ani = animation.FuncAnimation(
        fig=ax.figure,
        func=update,
        init_func=init,
        frames=len(x1_vals),
        interval=600,
        blit=False,
        repeat=False
    )
    return ani


# ================================
# Configuración general
# ================================
tol = 1e-5
max_iter = 50
x0_list = [np.array([[0.0], [0.0]]), np.array([[5.0], [2.0]])]

# ================================
# Sistema 1: x₁ + x₂ = 7 ; −2x₁ + 5x₂ = 0
# ================================
A1 = np.array([[1, 1], [-2, 5]], dtype=float)
b1 = np.array([[7], [0]], dtype=float)

for x0 in x0_list:
    _, traj1 = gauss_jacobi(A=A1, b=b1, x0=x0, tol=tol, max_iter=max_iter)

    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A1, b1)
    ani = animate_jacobi(ax, traj1, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 1: $x₁ + x₂ = 7$, $-2x₁ + 5x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()
    plt.show()


# ================================
# Sistema 2: x₁ + x₂ = 6 ; −2x₁ + x₂ = 0
# ================================
A2 = np.array([[1, 1], [-2, 1]], dtype=float)
b2 = np.array([[6], [0]], dtype=float)

for x0 in x0_list:
    _, traj2 = gauss_jacobi(A=A2, b=b2, x0=x0, tol=tol, max_iter=max_iter)

    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A2, b2)
    ani = animate_jacobi(ax, traj2, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 2: $x₁ + x₂ = 6$, $-2x₁ + x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()
    plt.show()
# Out:
# [07-15 17:40:08][INFO] i= 0 x: [[0. 0.]]
# [07-15 17:40:08][INFO] i= 1 x: [[7. 0.]]
# [07-15 17:40:08][INFO] i= 2 x: [[7.  2.8]]
# [07-15 17:40:08][INFO] i= 3 x: [[4.2 2.8]]
# [07-15 17:40:08][INFO] i= 4 x: [[4.2  1.68]]
# [07-15 17:40:08][INFO] i= 5 x: [[5.32 1.68]]
# [07-15 17:40:08][INFO] i= 6 x: [[5.32  2.128]]
# [07-15 17:40:08][INFO] i= 7 x: [[4.872 2.128]]
# [07-15 17:40:08][INFO] i= 8 x: [[4.872  1.9488]]
# [07-15 17:40:08][INFO] i= 9 x: [[5.0512 1.9488]]
# [07-15 17:40:08][INFO] i= 10 x: [[5.0512  2.02048]]
# [07-15 17:40:08][INFO] i= 11 x: [[4.97952 2.02048]]
# [07-15 17:40:08][INFO] i= 12 x: [[4.97952  1.991808]]
# [07-15 17:40:08][INFO] i= 13 x: [[5.008192 1.991808]]
# [07-15 17:40:08][INFO] i= 14 x: [[5.008192  2.0032768]]
# [07-15 17:40:08][INFO] i= 15 x: [[4.9967232 2.0032768]]
# [07-15 17:40:08][INFO] i= 16 x: [[4.9967232  1.99868928]]
# [07-15 17:40:08][INFO] i= 17 x: [[5.00131072 1.99868928]]
# [07-15 17:40:08][INFO] i= 18 x: [[5.00131072 2.00052429]]
# [07-15 17:40:08][INFO] i= 19 x: [[4.99947571 2.00052429]]
# [07-15 17:40:08][INFO] i= 20 x: [[4.99947571 1.99979028]]
# [07-15 17:40:08][INFO] i= 21 x: [[5.00020972 1.99979028]]
# [07-15 17:40:08][INFO] i= 22 x: [[5.00020972 2.00008389]]
# [07-15 17:40:08][INFO] i= 23 x: [[4.99991611 2.00008389]]
# [07-15 17:40:08][INFO] i= 24 x: [[4.99991611 1.99996645]]
# [07-15 17:40:08][INFO] i= 30 x: [[-98302.  65540.]]
# [07-15 17:40:08][INFO] i= 31 x: [[ -65534. -196604.]]
# [07-15 17:40:08][INFO] i= 32 x: [[ 196610. -131068.]]
# [07-15 17:40:08][INFO] i= 33 x: [[131074. 393220.]]
# [07-15 17:40:08][INFO] i= 34 x: [[-393214.  262148.]]
# [07-15 17:40:08][INFO] i= 35 x: [[-262142. -786428.]]
# [07-15 17:40:08][INFO] i= 36 x: [[ 786434. -524284.]]
# [07-15 17:40:08][INFO] i= 37 x: [[ 524290. 1572868.]]
# [07-15 17:40:08][INFO] i= 38 x: [[-1572862.  1048580.]]
# [07-15 17:40:08][INFO] i= 39 x: [[-1048574. -3145724.]]
# [07-15 17:40:08][INFO] i= 40 x: [[ 3145730. -2097148.]]
# [07-15 17:40:08][INFO] i= 41 x: [[2097154. 6291460.]]
# [07-15 17:40:08][INFO] i= 42 x: [[-6291454.  4194308.]]
# [07-15 17:40:08][INFO] i= 43 x: [[ -4194302. -12582908.]]
# [07-15 17:40:08][INFO] i= 44 x: [[12582914. -8388604.]]
# [07-15 17:40:08][INFO] i= 45 x: [[ 8388610. 25165828.]]
# [07-15 17:40:08][INFO] i= 46 x: [[-25165822.  16777220.]]
# [07-15 17:40:08][INFO] i= 47 x: [[-16777214. -50331644.]]
# [07-15 17:40:08][INFO] i= 48 x: [[ 50331650. -33554428.]]
# [07-15 17:40:08][INFO] i= 49 x: [[3.3554434e+07 1.0066330e+08]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from src.iterative_methods import gauss_jacobi  # NO modificamos tu función original


def plot_system(ax, A, b, xlim=(-10, 10)):
    """Dibuja las rectas del sistema de ecuaciones 2x2 en el plano"""
    x_vals = np.linspace(xlim[0], xlim[1], 400)
    for i in range(2):
        if A[i, 1] != 0:
            y_vals = (b[i] - A[i, 0] * x_vals) / A[i, 1]
            ax.plot(x_vals, y_vals, label=f"Ecuación {i+1}")
        else:
            x_const = b[i] / A[i, 0]
            ax.axvline(x_const, linestyle='--', label=f"Ecuación {i+1}")


def animate_jacobi(ax, traj, label):
    """Crea la animación de la trayectoria y devuelve el objeto ani"""
    traj_array = np.hstack(traj)
    x1_vals = traj_array[0, :]
    x2_vals = traj_array[1, :]

    line, = ax.plot([], [], 'o-', label=label)
    texts = []

    def init():
        line.set_data([], [])
        return line,

    def update(frame):
        line.set_data(x1_vals[:frame+1], x2_vals[:frame+1])
        for txt in texts:
            txt.remove()
        texts.clear()
        for i in range(frame+1):
            txt = ax.text(x1_vals[i], x2_vals[i], str(i), fontsize=7, ha='right')
            texts.append(txt)
        return line, *texts

    ani = animation.FuncAnimation(
        fig=ax.figure,
        func=update,
        init_func=init,
        frames=len(x1_vals),
        interval=600,
        blit=False,
        repeat=False
    )
    return ani


# ================================
# Configuración general
# ================================
tol = 1e-5
max_iter = 50
x0_list = [np.array([[2.0], [4.0]]), np.array([[4.0], [2.0]])]

# ================================
# Sistema 1: x₁ + x₂ = 7 ; −2x₁ + 5x₂ = 0
# ================================
A1 = np.array([[1, 1], [-2, 5]], dtype=float)
b1 = np.array([[7], [0]], dtype=float)

for i, x0 in enumerate(x0_list):
    _, traj1 = gauss_jacobi(A=A1, b=b1, x0=x0, tol=tol, max_iter=max_iter)
    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A1, b1)
    ani = animate_jacobi(ax, traj1, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 1: $x₁ + x₂ = 7$, $-2x₁ + 5x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()

    ani.save(f"sistema1_init{i+1}.gif", writer='pillow')
    plt.close(fig)

# ================================
# Sistema 2: x₁ + x₂ = 6 ; −2x₁ + x₂ = 0
# ================================
A2 = np.array([[1, 1], [-2, 1]], dtype=float)
b2 = np.array([[6], [0]], dtype=float)

for i, x0 in enumerate(x0_list):
    _, traj2 = gauss_jacobi(A=A2, b=b2, x0=x0, tol=tol, max_iter=max_iter)
    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A2, b2)
    ani = animate_jacobi(ax, traj2, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 2: $x₁ + x₂ = 6$, $-2x₁ + x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()

    ani.save(f"sistema2_init{i+1}.gif", writer='pillow')
    plt.close(fig)
# Out:
# [07-15 17:56:18][INFO] i= 0 x: [[2. 4.]]
# [07-15 17:56:18][INFO] i= 1 x: [[3.  0.8]]
# [07-15 17:56:18][INFO] i= 2 x: [[6.2 1.2]]
# [07-15 17:56:18][INFO] i= 3 x: [[5.8  2.48]]
# [07-15 17:56:18][INFO] i= 4 x: [[4.52 2.32]]
# [07-15 17:56:18][INFO] i= 5 x: [[4.68  1.808]]
# [07-15 17:56:18][INFO] i= 6 x: [[5.192 1.872]]
# [07-15 17:56:18][INFO] i= 7 x: [[5.128  2.0768]]
# [07-15 17:56:18][INFO] i= 8 x: [[4.9232 2.0512]]
# [07-15 17:56:18][INFO] i= 9 x: [[4.9488  1.96928]]
# [07-15 17:56:18][INFO] i= 10 x: [[5.03072 1.97952]]
# [07-15 17:56:18][INFO] i= 11 x: [[5.02048  2.012288]]
# [07-15 17:56:18][INFO] i= 12 x: [[4.987712 2.008192]]
# [07-15 17:56:18][INFO] i= 13 x: [[4.991808  1.9950848]]
# [07-15 17:56:18][INFO] i= 14 x: [[5.0049152 1.9967232]]
# [07-15 17:56:18][INFO] i= 15 x: [[5.0032768  2.00196608]]
# [07-15 17:56:18][INFO] i= 16 x: [[4.99803392 2.00131072]]
# [07-15 17:56:18][INFO] i= 17 x: [[4.99868928 1.99921357]]
# [07-15 17:56:18][INFO] i= 18 x: [[5.00078643 1.99947571]]
# [07-15 17:56:18][INFO] i= 19 x: [[5.00052429 2.00031457]]
# [07-15 17:56:18][INFO] i= 20 x: [[4.99968543 2.00020972]]
# [07-15 17:56:18][INFO] i= 21 x: [[4.99979028 1.99987417]]
# [07-15 17:56:18][INFO] i= 22 x: [[5.00012583 1.99991611]]
# [07-15 17:56:18][INFO] i= 23 x: [[5.00008389 2.00005033]]
# [07-15 17:56:18][INFO] i= 24 x: [[4.99994967 2.00003355]]
# [07-15 17:56:18][INFO] i= 25 x: [[4.99996645 1.99997987]]
# [07-15 17:56:18][INFO] i= 26 x: [[5.00002013 1.99998658]]
# [07-15 17:56:18][INFO] i= 27 x: [[5.00001342 2.00000805]]
# [07-15 17:56:18][INFO] i= 28 x: [[4.99999195 2.00000537]]
# [07-15 17:56:18][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>
# [07-15 17:56:20][INFO] i= 0 x: [[4. 2.]]
# [07-15 17:56:20][INFO] i= 1 x: [[5.  1.6]]
# [07-15 17:56:20][INFO] i= 2 x: [[5.4 2. ]]
# [07-15 17:56:20][INFO] i= 3 x: [[5.   2.16]]
# [07-15 17:56:20][INFO] i= 4 x: [[4.84 2.  ]]
# [07-15 17:56:20][INFO] i= 5 x: [[5.    1.936]]
# [07-15 17:56:20][INFO] i= 6 x: [[5.064 2.   ]]
# [07-15 17:56:20][INFO] i= 7 x: [[5.     2.0256]]
# [07-15 17:56:20][INFO] i= 8 x: [[4.9744 2.    ]]
# [07-15 17:56:20][INFO] i= 9 x: [[5.      1.98976]]
# [07-15 17:56:20][INFO] i= 10 x: [[5.01024 2.     ]]
# [07-15 17:56:20][INFO] i= 11 x: [[5.       2.004096]]
# [07-15 17:56:20][INFO] i= 12 x: [[4.995904 2.      ]]
# [07-15 17:56:20][INFO] i= 13 x: [[5.        1.9983616]]
# [07-15 17:56:20][INFO] i= 14 x: [[5.0016384 2.       ]]
# [07-15 17:56:20][INFO] i= 15 x: [[5.         2.00065536]]
# [07-15 17:56:20][INFO] i= 16 x: [[4.99934464 2.        ]]
# [07-15 17:56:20][INFO] i= 17 x: [[5.         1.99973786]]
# [07-15 17:56:20][INFO] i= 18 x: [[5.00026214 2.        ]]
# [07-15 17:56:20][INFO] i= 19 x: [[5.         2.00010486]]
# [07-15 17:56:20][INFO] i= 20 x: [[4.99989514 2.        ]]
# [07-15 17:56:20][INFO] i= 21 x: [[5.         1.99995806]]
# [07-15 17:56:20][INFO] i= 22 x: [[5.00004194 2.        ]]
# [07-15 17:56:20][INFO] i= 23 x: [[5.         2.00001678]]
# [07-15 17:56:20][INFO] i= 24 x: [[4.99998322 2.        ]]
# [07-15 17:56:20][INFO] i= 25 x: [[5.         1.99999329]]
# [07-15 17:56:20][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>
# [07-15 17:56:22][INFO] i= 0 x: [[2. 4.]]
# [07-15 17:56:22][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>
# [07-15 17:56:22][INFO] i= 0 x: [[4. 2.]]
# [07-15 17:56:22][INFO] i= 44 x: [[ 8388610. -8388604.]]
# [07-15 17:56:22][INFO] i= 45 x: [[ 8388610. 16777220.]]
# [07-15 17:56:22][INFO] i= 46 x: [[-16777214.  16777220.]]
# [07-15 17:56:22][INFO] i= 47 x: [[-16777214. -33554428.]]
# [07-15 17:56:22][INFO] i= 48 x: [[ 33554434. -33554428.]]
# [07-15 17:56:22][INFO] i= 49 x: [[33554434. 67108868.]]
# [07-15 17:56:22][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from src.iterative_methods import gauss_jacobi  # Tu implementación original sin modificar


def plot_system(ax, A, b, xlim=(-10, 10)):
    """Dibuja las líneas correspondientes a las ecuaciones del sistema Ax = b"""
    x_vals = np.linspace(xlim[0], xlim[1], 400)
    for i in range(2):
        if A[i, 1] != 0:
            y_vals = (b[i] - A[i, 0] * x_vals) / A[i, 1]
            ax.plot(x_vals, y_vals, label=f"Ecuación {i+1}")
        else:
            x_const = b[i] / A[i, 0]
            ax.axvline(x_const, linestyle='--', label=f"Ecuación {i+1}")


def aplicar_relajacion(trayectoria, omega=0.5):
    """Aplica relajación externa a la trayectoria iterativa"""
    relajada = [trayectoria[0].copy()]
    for k in range(1, len(trayectoria)):
        x_prev = relajada[-1]
        x_curr = trayectoria[k]
        x_relaxed = (1 - omega) * x_prev + omega * x_curr
        relajada.append(x_relaxed)
    return relajada


def animate_jacobi(ax, traj, label):
    """Crea animación cuadro por cuadro de la trayectoria"""
    traj_array = np.hstack(traj)
    x1_vals = traj_array[0, :]
    x2_vals = traj_array[1, :]

    line, = ax.plot([], [], 'o-', label=label)
    texts = []

    def init():
        line.set_data([], [])
        return line,

    def update(frame):
        line.set_data(x1_vals[:frame + 1], x2_vals[:frame + 1])
        for txt in texts:
            txt.remove()
        texts.clear()
        for i in range(frame + 1):
            txt = ax.text(x1_vals[i], x2_vals[i], str(i), fontsize=7, ha='right')
            texts.append(txt)
        return line, *texts

    ani = animation.FuncAnimation(
        fig=ax.figure,
        func=update,
        init_func=init,
        frames=len(x1_vals),
        interval=600,
        blit=False,
        repeat=False
    )
    return ani


# ==================================
# Configuración
# ==================================
tol = 1e-5
max_iter = 50
x0_list = [np.array([[0.0], [0.0]]), np.array([[5.0], [2.0]])]

# ==================================
# Sistema 1: x₁ + x₂ = 7 ; −2x₁ + 5x₂ = 0
# ==================================
A1 = np.array([[1, 1], [-2, 5]], dtype=float)
b1 = np.array([[7], [0]], dtype=float)

for i, x0 in enumerate(x0_list):
    _, traj1 = gauss_jacobi(A=A1, b=b1, x0=x0, tol=tol, max_iter=max_iter)
    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A1, b1)
    ani = animate_jacobi(ax, traj1, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 1: $x₁ + x₂ = 7$, $-2x₁ + 5x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()

    ani.save(f"sistema1_init{i + 1}.gif", writer='pillow')
    plt.close(fig)


# ==================================
# Sistema 2: x₁ + x₂ = 6 ; −2x₁ + x₂ = 0
# ==================================
A2 = np.array([[1, 1], [-2, 1]], dtype=float)
b2 = np.array([[6], [0]], dtype=float)

for i, x0 in enumerate(x0_list):
    _, traj2 = gauss_jacobi(A=A2, b=b2, x0=x0, tol=tol, max_iter=max_iter)
    traj2 = aplicar_relajacion(traj2, omega=0.5)  # Aplicamos relajación externa
    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A2, b2)
    ani = animate_jacobi(ax, traj2, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 2: $x₁ + x₂ = 6$, $-2x₁ + x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()

    ani.save(f"sistema2_init{i + 1}.gif", writer='pillow')
    plt.close(fig)
# Out:
# [07-15 17:46:45][INFO] i= 0 x: [[0. 0.]]
# [07-15 17:46:45][INFO] i= 1 x: [[7. 0.]]
# [07-15 17:46:45][INFO] i= 2 x: [[7.  2.8]]
# [07-15 17:46:45][INFO] i= 3 x: [[4.2 2.8]]
# [07-15 17:46:45][INFO] i= 4 x: [[4.2  1.68]]
# [07-15 17:46:45][INFO] i= 5 x: [[5.32 1.68]]
# [07-15 17:46:45][INFO] i= 6 x: [[5.32  2.128]]
# [07-15 17:46:45][INFO] i= 7 x: [[4.872 2.128]]
# [07-15 17:46:45][INFO] i= 8 x: [[4.872  1.9488]]
# [07-15 17:46:45][INFO] i= 9 x: [[5.0512 1.9488]]
# [07-15 17:46:45][INFO] i= 10 x: [[5.0512  2.02048]]
# [07-15 17:46:45][INFO] i= 11 x: [[4.97952 2.02048]]
# [07-15 17:46:45][INFO] i= 12 x: [[4.97952  1.991808]]
# [07-15 17:46:45][INFO] i= 13 x: [[5.008192 1.991808]]
# [07-15 17:46:45][INFO] i= 14 x: [[5.008192  2.0032768]]
# [07-15 17:46:45][INFO] i= 15 x: [[4.9967232 2.0032768]]
# [07-15 17:46:45][INFO] i= 16 x: [[4.9967232  1.99868928]]
# [07-15 17:46:45][INFO] i= 17 x: [[5.00131072 1.99868928]]
# [07-15 17:46:45][INFO] i= 18 x: [[5.00131072 2.00052429]]
# [07-15 17:46:45][INFO] i= 19 x: [[4.99947571 2.00052429]]
# [07-15 17:46:45][INFO] i= 20 x: [[4.99947571 1.99979028]]
# [07-15 17:46:45][INFO] i= 21 x: [[5.00020972 1.99979028]]
# [07-15 17:46:45][INFO] i= 22 x: [[5.00020972 2.00008389]]
# [07-15 17:46:45][INFO] i= 23 x: [[4.99991611 2.00008389]]
# [07-15 17:46:45][INFO] i= 24 x: [[4.99991611 1.99996645]]
# [07-15 17:46:45][INFO] i= 25 x: [[5.00003355 1.99996645]]
# [07-15 17:46:52][INFO] i= 28 x: [[ 49154. -32764.]]
# [07-15 17:46:52][INFO] i= 29 x: [[32770. 98308.]]
# [07-15 17:46:52][INFO] i= 30 x: [[-98302.  65540.]]
# [07-15 17:46:52][INFO] i= 31 x: [[ -65534. -196604.]]
# [07-15 17:46:52][INFO] i= 32 x: [[ 196610. -131068.]]
# [07-15 17:46:52][INFO] i= 33 x: [[131074. 393220.]]
# [07-15 17:46:52][INFO] i= 34 x: [[-393214.  262148.]]
# [07-15 17:46:52][INFO] i= 35 x: [[-262142. -786428.]]
# [07-15 17:46:52][INFO] i= 36 x: [[ 786434. -524284.]]
# [07-15 17:46:52][INFO] i= 37 x: [[ 524290. 1572868.]]
# [07-15 17:46:52][INFO] i= 38 x: [[-1572862.  1048580.]]
# [07-15 17:46:52][INFO] i= 39 x: [[-1048574. -3145724.]]
# [07-15 17:46:52][INFO] i= 40 x: [[ 3145730. -2097148.]]
# [07-15 17:46:52][INFO] i= 41 x: [[2097154. 6291460.]]
# [07-15 17:46:52][INFO] i= 42 x: [[-6291454.  4194308.]]
# [07-15 17:46:52][INFO] i= 43 x: [[ -4194302. -12582908.]]
# [07-15 17:46:52][INFO] i= 44 x: [[12582914. -8388604.]]
# [07-15 17:46:52][INFO] i= 45 x: [[ 8388610. 25165828.]]
# [07-15 17:46:52][INFO] i= 46 x: [[-25165822.  16777220.]]
# [07-15 17:46:52][INFO] i= 47 x: [[-16777214. -50331644.]]
# [07-15 17:46:52][INFO] i= 48 x: [[ 50331650. -33554428.]]
# [07-15 17:46:52][INFO] i= 49 x: [[3.3554434e+07 1.0066330e+08]]
# [07-15 17:46:52][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from src.iterative_methods import gauss_jacobi  # Asegúrate de que esta función esté correctamente definida


def plot_system(ax, A, b, xlim=(-10, 10)):
    x_vals = np.linspace(xlim[0], xlim[1], 400)
    for i in range(2):
        if A[i, 1] != 0:
            y_vals = (b[i] - A[i, 0] * x_vals) / A[i, 1]
            ax.plot(x_vals, y_vals, label=f"Ecuación {i+1}")
        else:
            x_const = b[i] / A[i, 0]
            ax.axvline(x_const, linestyle='--', label=f"Ecuación {i+1}")


def aplicar_relajacion(trayectoria, omega=0.5):
    relajada = [trayectoria[0].copy()]
    for k in range(1, len(trayectoria)):
        x_prev = relajada[-1]
        x_curr = trayectoria[k]
        x_relaxed = (1 - omega) * x_prev + omega * x_curr
        relajada.append(x_relaxed)
    return relajada


def animate_jacobi(ax, traj, label):
    traj_array = np.hstack(traj)
    x1_vals = traj_array[0, :]
    x2_vals = traj_array[1, :]

    line, = ax.plot([], [], 'o-', label=label)
    texts = []

    def init():
        line.set_data([], [])
        return line,

    def update(frame):
        line.set_data(x1_vals[:frame + 1], x2_vals[:frame + 1])
        for txt in texts:
            txt.remove()
        texts.clear()
        for i in range(frame + 1):
            txt = ax.text(x1_vals[i], x2_vals[i], str(i), fontsize=7, ha='right')
            texts.append(txt)
        return line, *texts

    ani = animation.FuncAnimation(
        fig=ax.figure,
        func=update,
        init_func=init,
        frames=len(x1_vals),
        interval=600,
        blit=False,
        repeat=False
    )
    return ani


# ==================================
# Configuración general
# ==================================
tol = 1e-5
max_iter = 50

# Estimaciones iniciales
x0_list = [
    np.array([[0.0], [0.0]]),        # Divergente
    np.array([[5.0], [2.0]]),        # También puede diverger
    np.array([[1.8], [3.6]])         # Aproximadamente cerca de (2, 4) → Convergente
]

# ==================================
# Sistema 1: x₁ + x₂ = 7 ; −2x₁ + 5x₂ = 0
# ==================================
A1 = np.array([[1, 1], [-2, 5]], dtype=float)
b1 = np.array([[7], [0]], dtype=float)

for i, x0 in enumerate(x0_list[:2]):  # Solo primeras 2 para el sistema 1
    _, traj1 = gauss_jacobi(A=A1, b=b1, x0=x0, tol=tol, max_iter=max_iter)

    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A1, b1)
    ani = animate_jacobi(ax, traj1, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 1: $x₁ + x₂ = 7$, $-2x₁ + 5x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()

    ani.save(f"sistema1_init{i + 1}.gif", writer='pillow')
    plt.close(fig)

# ==================================
# Sistema 2: x₁ + x₂ = 6 ; −2x₁ + x₂ = 0
# ==================================
A2 = np.array([[1, 1], [-2, 1]], dtype=float)
b2 = np.array([[6], [0]], dtype=float)

for i, x0 in enumerate(x0_list):  # Ahora usamos las 3 estimaciones
    _, traj2 = gauss_jacobi(A=A2, b=b2, x0=x0, tol=tol, max_iter=max_iter)
    traj2 = aplicar_relajacion(traj2, omega=0.5)

    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A2, b2)
    ani = animate_jacobi(ax, traj2, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 2: $x₁ + x₂ = 6$, $-2x₁ + x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()

    ani.save(f"sistema2_init{i + 1}.gif", writer='pillow')
    plt.close(fig)
# Out:
# [07-15 20:48:32][INFO] 2025-07-15 20:48:32.009152
# [07-15 20:48:32][INFO] 2025-07-15 20:48:32.013753
# [07-15 20:48:32][INFO] i= 0 x: [[0. 0.]]
# [07-15 20:48:32][INFO] i= 1 x: [[7. 0.]]
# [07-15 20:48:32][INFO] i= 2 x: [[7.  2.8]]
# [07-15 20:48:32][INFO] i= 3 x: [[4.2 2.8]]
# [07-15 20:48:32][INFO] i= 4 x: [[4.2  1.68]]
# [07-15 20:48:32][INFO] i= 5 x: [[5.32 1.68]]
# [07-15 20:48:32][INFO] i= 6 x: [[5.32  2.128]]
# [07-15 20:48:32][INFO] i= 7 x: [[4.872 2.128]]
# [07-15 20:48:32][INFO] i= 8 x: [[4.872  1.9488]]
# [07-15 20:48:32][INFO] i= 9 x: [[5.0512 1.9488]]
# [07-15 20:48:32][INFO] i= 10 x: [[5.0512  2.02048]]
# [07-15 20:48:32][INFO] i= 11 x: [[4.97952 2.02048]]
# [07-15 20:48:32][INFO] i= 12 x: [[4.97952  1.991808]]
# [07-15 20:48:32][INFO] i= 13 x: [[5.008192 1.991808]]
# [07-15 20:48:32][INFO] i= 14 x: [[5.008192  2.0032768]]
# [07-15 20:48:32][INFO] i= 15 x: [[4.9967232 2.0032768]]
# [07-15 20:48:32][INFO] i= 16 x: [[4.9967232  1.99868928]]
# [07-15 20:48:32][INFO] i= 17 x: [[5.00131072 1.99868928]]
# [07-15 20:48:32][INFO] i= 18 x: [[5.00131072 2.00052429]]
# [07-15 20:48:32][INFO] i= 19 x: [[4.99947571 2.00052429]]
# [07-15 20:48:32][INFO] i= 20 x: [[4.99947571 1.99979028]]
# [07-15 20:48:32][INFO] i= 21 x: [[5.00020972 1.99979028]]
# [07-15 20:48:32][INFO] i= 22 x: [[5.00020972 2.00008389]]
# [07-15 20:48:32][INFO] i= 23 x: [[4.99991611 2.00008389]]
# [07-15 20:48:32][INFO] i= 24 x: [[4.99991611 1.99996645]]
# [07-15 20:48:32][INFO] i= 25 x: [[5.00003355 1.99996645]]
# [07-15 20:48:32][INFO] i= 26 x: [[5.00003355 2.00001342]]
# [07-15 20:48:32][INFO] i= 27 x: [[4.99998658 2.00001342]]
# [07-15 20:48:32][INFO] i= 28 x: [[4.99998658 1.99999463]]
# [07-15 20:48:32][INFO] i= 29 x: [[5.00000537 1.99999463]]
# [07-15 20:48:32][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>
# [07-15 20:48:39][INFO] i= 0 x: [[5. 2.]]
# [07-15 20:48:39][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>
# [07-15 20:48:39][INFO] i= 0 x: [[0. 0.]]
# [07-15 20:48:39][INFO] i= 1 x: [[6. 0.]]
# [07-15 20:48:39][INFO] i= 2 x: [[ 6. 12.]]
# [07-15 20:48:39][INFO] i= 3 x: [[-6. 12.]]
# [07-15 20:48:39][INFO] i= 4 x: [[ -6. -12.]]
# [07-15 20:48:39][INFO] i= 5 x: [[ 18. -12.]]
# [07-15 20:48:39][INFO] i= 6 x: [[18. 36.]]
# [07-15 20:48:39][INFO] i= 7 x: [[-30.  36.]]
# [07-15 20:48:39][INFO] i= 8 x: [[-30. -60.]]
# [07-15 20:48:39][INFO] i= 9 x: [[ 66. -60.]]
# [07-15 20:48:39][INFO] i= 10 x: [[ 66. 132.]]
# [07-15 20:48:39][INFO] i= 11 x: [[-126.  132.]]
# [07-15 20:48:39][INFO] i= 12 x: [[-126. -252.]]
# [07-15 20:48:39][INFO] i= 13 x: [[ 258. -252.]]
# [07-15 20:48:39][INFO] i= 14 x: [[258. 516.]]
# [07-15 20:48:39][INFO] i= 15 x: [[-510.  516.]]
# [07-15 20:48:39][INFO] i= 16 x: [[ -510. -1020.]]
# [07-15 20:48:39][INFO] i= 17 x: [[ 1026. -1020.]]
# [07-15 20:48:39][INFO] i= 18 x: [[1026. 2052.]]
# [07-15 20:48:39][INFO] i= 19 x: [[-2046.  2052.]]
# [07-15 20:48:39][INFO] i= 20 x: [[-2046. -4092.]]
# [07-15 20:48:39][INFO] i= 21 x: [[ 4098. -4092.]]
# [07-15 20:48:39][INFO] i= 22 x: [[4098. 8196.]]
# [07-15 20:48:39][INFO] i= 23 x: [[-8190.  8196.]]
# [07-15 20:48:39][INFO] i= 24 x: [[ -8190. -16380.]]
# [07-15 20:48:39][INFO] i= 25 x: [[ 16386. -16380.]]
# [07-15 20:48:39][INFO] i= 26 x: [[16386. 32772.]]
# [07-15 20:48:39][INFO] i= 27 x: [[-32766.  32772.]]
# [07-15 20:48:39][INFO] i= 28 x: [[-32766. -65532.]]
# [07-15 20:48:39][INFO] i= 29 x: [[ 65538. -65532.]]
# [07-15 20:48:39][INFO] i= 30 x: [[ 65538. 131076.]]
# [07-15 20:48:39][INFO] i= 31 x: [[-131070.  131076.]]
# [07-15 20:48:39][INFO] i= 32 x: [[-131070. -262140.]]
# [07-15 20:48:39][INFO] i= 33 x: [[ 262146. -262140.]]
# [07-15 20:48:39][INFO] i= 34 x: [[262146. 524292.]]
# [07-15 20:48:39][INFO] i= 35 x: [[-524286.  524292.]]
# [07-15 20:48:39][INFO] i= 36 x: [[ -524286. -1048572.]]
# [07-15 20:48:39][INFO] i= 37 x: [[ 1048578. -1048572.]]
# [07-15 20:48:39][INFO] i= 38 x: [[1048578. 2097156.]]
# [07-15 20:48:39][INFO] i= 39 x: [[-2097150.  2097156.]]
# [07-15 20:48:39][INFO] i= 40 x: [[-2097150. -4194300.]]
# [07-15 20:48:39][INFO] i= 41 x: [[ 4194306. -4194300.]]
# [07-15 20:48:39][INFO] i= 42 x: [[4194306. 8388612.]]
# [07-15 20:48:39][INFO] i= 43 x: [[-8388606.  8388612.]]
# [07-15 20:48:39][INFO] i= 44 x: [[ -8388606. -16777212.]]
# [07-15 20:48:39][INFO] i= 45 x: [[ 16777218. -16777212.]]
# [07-15 20:48:39][INFO] i= 46 x: [[16777218. 33554436.]]
# [07-15 20:48:39][INFO] i= 47 x: [[-33554430.  33554436.]]
# [07-15 20:48:39][INFO] i= 48 x: [[-33554430. -67108860.]]
# [07-15 20:48:39][INFO] i= 49 x: [[ 67108866. -67108860.]]
# [07-15 20:48:39][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>
# [07-15 20:48:50][INFO] i= 0 x: [[5. 2.]]
# [07-15 20:48:50][INFO] i= 1 x: [[ 4. 10.]]
# [07-15 20:48:50][INFO] i= 2 x: [[-4.  8.]]
# [07-15 20:48:50][INFO] i= 3 x: [[-2. -8.]]
# [07-15 20:48:50][INFO] i= 4 x: [[14. -4.]]
# [07-15 20:48:50][INFO] i= 5 x: [[10. 28.]]
# [07-15 20:48:50][INFO] i= 6 x: [[-22.  20.]]
# [07-15 20:48:50][INFO] i= 7 x: [[-14. -44.]]
# [07-15 20:48:50][INFO] i= 8 x: [[ 50. -28.]]
# [07-15 20:48:50][INFO] i= 9 x: [[ 34. 100.]]
# [07-15 20:48:50][INFO] i= 10 x: [[-94.  68.]]
# [07-15 20:48:50][INFO] i= 11 x: [[ -62. -188.]]
# [07-15 20:48:50][INFO] i= 12 x: [[ 194. -124.]]
# [07-15 20:48:50][INFO] i= 13 x: [[130. 388.]]
# [07-15 20:48:50][INFO] i= 14 x: [[-382.  260.]]
# [07-15 20:48:50][INFO] i= 15 x: [[-254. -764.]]
# [07-15 20:48:50][INFO] i= 16 x: [[ 770. -508.]]
# [07-15 20:48:50][INFO] i= 17 x: [[ 514. 1540.]]
# [07-15 20:48:50][INFO] i= 18 x: [[-1534.  1028.]]
# [07-15 20:48:50][INFO] i= 19 x: [[-1022. -3068.]]
# [07-15 20:48:50][INFO] i= 20 x: [[ 3074. -2044.]]
# [07-15 20:48:50][INFO] i= 21 x: [[2050. 6148.]]
# [07-15 20:48:50][INFO] i= 22 x: [[-6142.  4100.]]
# [07-15 20:48:50][INFO] i= 23 x: [[ -4094. -12284.]]
# [07-15 20:48:50][INFO] i= 24 x: [[12290. -8188.]]
# [07-15 20:48:50][INFO] i= 25 x: [[ 8194. 24580.]]
# [07-15 20:48:50][INFO] i= 26 x: [[-24574.  16388.]]
# [07-15 20:48:50][INFO] i= 27 x: [[-16382. -49148.]]
# [07-15 20:48:50][INFO] i= 28 x: [[ 49154. -32764.]]
# [07-15 20:48:50][INFO] i= 29 x: [[32770. 98308.]]
# [07-15 20:48:50][INFO] i= 30 x: [[-98302.  65540.]]
# [07-15 20:48:50][INFO] i= 31 x: [[ -65534. -196604.]]
# [07-15 20:48:50][INFO] i= 32 x: [[ 196610. -131068.]]
# [07-15 20:48:50][INFO] i= 33 x: [[131074. 393220.]]
# [07-15 20:48:50][INFO] i= 34 x: [[-393214.  262148.]]
# [07-15 20:48:50][INFO] i= 35 x: [[-262142. -786428.]]
# [07-15 20:48:50][INFO] i= 36 x: [[ 786434. -524284.]]
# [07-15 20:48:50][INFO] i= 37 x: [[ 524290. 1572868.]]
# [07-15 20:48:50][INFO] i= 38 x: [[-1572862.  1048580.]]
# [07-15 20:48:50][INFO] i= 39 x: [[-1048574. -3145724.]]
# [07-15 20:48:50][INFO] i= 40 x: [[ 3145730. -2097148.]]
# [07-15 20:48:50][INFO] i= 41 x: [[2097154. 6291460.]]
# [07-15 20:48:50][INFO] i= 42 x: [[-6291454.  4194308.]]
# [07-15 20:48:50][INFO] i= 43 x: [[ -4194302. -12582908.]]
# [07-15 20:48:50][INFO] i= 44 x: [[12582914. -8388604.]]
# [07-15 20:48:50][INFO] i= 45 x: [[ 8388610. 25165828.]]
# [07-15 20:48:50][INFO] i= 46 x: [[-25165822.  16777220.]]
# [07-15 20:48:50][INFO] i= 47 x: [[-16777214. -50331644.]]
# [07-15 20:48:50][INFO] i= 48 x: [[ 50331650. -33554428.]]
# [07-15 20:48:50][INFO] i= 49 x: [[3.3554434e+07 1.0066330e+08]]
# [07-15 20:49:01][INFO] i= 40 x: [[-209713.2 -419426.4]]
# [07-15 20:49:01][INFO] i= 41 x: [[ 419432.4 -419426.4]]
# [07-15 20:49:01][INFO] i= 42 x: [[419432.4 838864.8]]
# [07-15 20:49:01][INFO] i= 43 x: [[-838858.8  838864.8]]
# [07-15 20:49:01][INFO] i= 44 x: [[ -838858.8 -1677717.6]]
# [07-15 20:49:01][INFO] i= 45 x: [[ 1677723.6 -1677717.6]]
# [07-15 20:49:01][INFO] i= 46 x: [[1677723.6 3355447.2]]
# [07-15 20:49:01][INFO] i= 47 x: [[-3355441.2  3355447.2]]
# [07-15 20:49:01][INFO] i= 48 x: [[-3355441.2 -6710882.4]]
# [07-15 20:49:01][INFO] i= 49 x: [[ 6710888.4 -6710882.4]]
# [07-15 20:49:02][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from src.iterative_methods import gauss_jacobi  

def plot_system(ax, A, b, xlim=(-10, 10)):
    x_vals = np.linspace(xlim[0], xlim[1], 400)
    for i in range(2):
        if A[i, 1] != 0:
            y_vals = (b[i] - A[i, 0] * x_vals) / A[i, 1]
            ax.plot(x_vals, y_vals, label=f"Ecuación {i+1}")
        else:
            x_const = b[i] / A[i, 0]
            ax.axvline(x_const, linestyle='--', label=f"Ecuación {i+1}")


def aplicar_relajacion(trayectoria, omega=0.5):
    relajada = [trayectoria[0].copy()]
    for k in range(1, len(trayectoria)):
        x_prev = relajada[-1]
        x_curr = trayectoria[k]
        x_relaxed = (1 - omega) * x_prev + omega * x_curr
        relajada.append(x_relaxed)
    return relajada


def animate_jacobi(ax, traj, label):
    traj_array = np.hstack(traj)
    x1_vals = traj_array[0, :]
    x2_vals = traj_array[1, :]

    line, = ax.plot([], [], 'o-', label=label)
    texts = []

    def init():
        line.set_data([], [])
        return line,

    def update(frame):
        line.set_data(x1_vals[:frame + 1], x2_vals[:frame + 1])
        for txt in texts:
            txt.remove()
        texts.clear()
        for i in range(frame + 1):
            txt = ax.text(x1_vals[i], x2_vals[i], str(i), fontsize=7, ha='right')
            texts.append(txt)
        return line, *texts

    ani = animation.FuncAnimation(
        fig=ax.figure,
        func=update,
        init_func=init,
        frames=len(x1_vals),
        interval=600,
        blit=False,
        repeat=False
    )
    return ani


# ==================================
# Configuración general
# ==================================
tol = 1e-5
max_iter = 50

# Estimaciones iniciales
x0_list = [
    np.array([[0.0], [0.0]]),        # Divergente
    np.array([[5.0], [2.0]]),        # También puede diverger
    np.array([[1.8], [3.6]])         # Aproximadamente cerca de (2, 4) → Convergente
]
# ==================================
# Sistema 1: x₁ + x₂ = 7 ; −2x₁ + 5x₂ = 0
# ==================================
A1 = np.array([[1, 1], [-2, 5]], dtype=float)
b1 = np.array([[7], [0]], dtype=float)

print("\n--- Sistema 1 ---")
for i, x0 in enumerate(x0_list):
    x_sol, traj1 = gauss_jacobi(A=A1, b=b1, x0=x0, tol=tol, max_iter=max_iter)
    diverge = any(np.linalg.norm(x) > 1e6 for x in traj1)

    if diverge:
        print(f"⚠️  Divergencia detectada en Sistema 1 con x0 = {x0.ravel().tolist()}")
    else:
        print(f"✅ Convergencia en Sistema 1 con x0 = {x0.ravel().tolist()}")

    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A1, b1)
    ani = animate_jacobi(ax, traj1, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 1: $x₁ + x₂ = 7$, $-2x₁ + 5x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()

    ani.save(f"sistema1_init{i + 1}.gif", writer='pillow')
    plt.close(fig)


# ==================================
# Sistema 2: x₁ + x₂ = 6 ; −2x₁ + x₂ = 0
# ==================================
A2 = np.array([[1, 1], [-2, 1]], dtype=float)
b2 = np.array([[6], [0]], dtype=float)

print("\n--- Sistema 2 ---")
for i, x0 in enumerate(x0_list):
    x_sol, traj2 = gauss_jacobi(A=A2, b=b2, x0=x0, tol=tol, max_iter=max_iter)
    traj2 = aplicar_relajacion(traj2, omega=0.5)
    diverge = any(np.linalg.norm(x) > 1e6 for x in traj2)

    if diverge:
        print(f"⚠️  Divergencia detectada en Sistema 2 con x0 = {x0.ravel().tolist()}")
    else:
        print(f"✅ Convergencia en Sistema 2 con x0 = {x0.ravel().tolist()}")

    fig, ax = plt.subplots(figsize=(6, 6))
    plot_system(ax, A2, b2)
    ani = animate_jacobi(ax, traj2, label=f"Inicial: {x0.ravel().tolist()}")

    ax.set_title("Sistema 2: $x₁ + x₂ = 6$, $-2x₁ + x₂ = 0$")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    ax.axhline(0, color='gray', lw=0.5)
    ax.axvline(0, color='gray', lw=0.5)
    ax.grid(True)
    ax.axis('equal')
    ax.legend()
    plt.tight_layout()

    ani.save(f"sistema2_init{i + 1}.gif", writer='pillow')
    plt.close(fig)
# Out:
# --- Sistema 1 ---
# [07-15 21:06:59][INFO] i= 0 x: [[0. 0.]]
# [07-15 21:06:59][INFO] i= 1 x: [[7. 0.]]
# [07-15 21:06:59][INFO] i= 2 x: [[7.  2.8]]
# [07-15 21:06:59][INFO] i= 3 x: [[4.2 2.8]]
# [07-15 21:06:59][INFO] i= 4 x: [[4.2  1.68]]
# [07-15 21:06:59][INFO] i= 5 x: [[5.32 1.68]]
# [07-15 21:06:59][INFO] i= 6 x: [[5.32  2.128]]
# [07-15 21:06:59][INFO] i= 7 x: [[4.872 2.128]]
# [07-15 21:06:59][INFO] i= 8 x: [[4.872  1.9488]]
# [07-15 21:06:59][INFO] i= 9 x: [[5.0512 1.9488]]
# [07-15 21:06:59][INFO] i= 10 x: [[5.0512  2.02048]]
# [07-15 21:06:59][INFO] i= 11 x: [[4.97952 2.02048]]
# [07-15 21:06:59][INFO] i= 12 x: [[4.97952  1.991808]]
# [07-15 21:06:59][INFO] i= 13 x: [[5.008192 1.991808]]
# [07-15 21:06:59][INFO] i= 14 x: [[5.008192  2.0032768]]
# [07-15 21:06:59][INFO] i= 15 x: [[4.9967232 2.0032768]]
# [07-15 21:06:59][INFO] i= 16 x: [[4.9967232  1.99868928]]
# [07-15 21:06:59][INFO] i= 17 x: [[5.00131072 1.99868928]]
# [07-15 21:06:59][INFO] i= 18 x: [[5.00131072 2.00052429]]
# [07-15 21:06:59][INFO] i= 19 x: [[4.99947571 2.00052429]]
# [07-15 21:06:59][INFO] i= 20 x: [[4.99947571 1.99979028]]
# [07-15 21:06:59][INFO] i= 21 x: [[5.00020972 1.99979028]]
# [07-15 21:06:59][INFO] i= 22 x: [[5.00020972 2.00008389]]
# [07-15 21:06:59][INFO] i= 23 x: [[4.99991611 2.00008389]]
# [07-15 21:06:59][INFO] i= 24 x: [[4.99991611 1.99996645]]
# [07-15 21:06:59][INFO] i= 25 x: [[5.00003355 1.99996645]]
# [07-15 21:06:59][INFO] i= 26 x: [[5.00003355 2.00001342]]
# [07-15 21:06:59][INFO] i= 27 x: [[4.99998658 2.00001342]]
# [07-15 21:06:59][INFO] i= 28 x: [[4.99998658 1.99999463]]
# [07-15 21:06:59][INFO] i= 29 x: [[5.00000537 1.99999463]]
# ✅ Convergencia en Sistema 1 con x0 = [0.0, 0.0]
# [07-15 21:06:59][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>
# [07-15 21:07:05][INFO] i= 0 x: [[5. 2.]]
# ✅ Convergencia en Sistema 1 con x0 = [5.0, 2.0]
# [07-15 21:07:05][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>
# [07-15 21:07:05][INFO] i= 0 x: [[1.8 3.6]]
# [07-15 21:07:05][INFO] i= 1 x: [[3.4  0.72]]
# [07-15 21:07:05][INFO] i= 2 x: [[6.28 1.36]]
# [07-15 21:07:05][INFO] i= 3 x: [[5.64  2.512]]
# [07-15 21:07:05][INFO] i= 4 x: [[4.488 2.256]]
# [07-15 21:07:05][INFO] i= 5 x: [[4.744  1.7952]]
# [07-15 21:07:05][INFO] i= 6 x: [[5.2048 1.8976]]
# [07-15 21:07:05][INFO] i= 7 x: [[5.1024  2.08192]]
# [07-15 21:07:05][INFO] i= 8 x: [[4.91808 2.04096]]
# [07-15 21:07:05][INFO] i= 9 x: [[4.95904  1.967232]]
# [07-15 21:07:05][INFO] i= 10 x: [[5.032768 1.983616]]
# [07-15 21:07:05][INFO] i= 11 x: [[5.016384  2.0131072]]
# [07-15 21:07:05][INFO] i= 12 x: [[4.9868928 2.0065536]]
# [07-15 21:07:05][INFO] i= 13 x: [[4.9934464  1.99475712]]
# [07-15 21:07:05][INFO] i= 14 x: [[5.00524288 1.99737856]]
# [07-15 21:07:05][INFO] i= 15 x: [[5.00262144 2.00209715]]
# [07-15 21:07:05][INFO] i= 16 x: [[4.99790285 2.00104858]]
# [07-15 21:07:05][INFO] i= 17 x: [[4.99895142 1.99916114]]
# [07-15 21:07:05][INFO] i= 18 x: [[5.00083886 1.99958057]]
# [07-15 21:07:05][INFO] i= 19 x: [[5.00041943 2.00033554]]
# [07-15 21:07:05][INFO] i= 20 x: [[4.99966446 2.00016777]]
# [07-15 21:07:05][INFO] i= 21 x: [[4.99983223 1.99986578]]
# [07-15 21:07:05][INFO] i= 22 x: [[5.00013422 1.99993289]]
# [07-15 21:07:05][INFO] i= 23 x: [[5.00006711 2.00005369]]
# [07-15 21:07:05][INFO] i= 24 x: [[4.99994631 2.00002684]]
# [07-15 21:07:05][INFO] i= 25 x: [[4.99997316 1.99997853]]
# [07-15 21:07:05][INFO] i= 26 x: [[5.00002147 1.99998926]]
# [07-15 21:07:05][INFO] i= 27 x: [[5.00001074 2.00000859]]
# [07-15 21:07:05][INFO] i= 28 x: [[4.99999141 2.00000429]]
# ✅ Convergencia en Sistema 1 con x0 = [1.8, 3.6]
# [07-15 21:07:05][INFO] Animation.save using <class 'matplotlib.animation.PillowWriter'>
#
# --- Sistema 2 ---
# [07-15 21:07:11][INFO] i= 0 x: [[0. 0.]]
# [07-15 21:07:11][INFO] i= 1 x: [[6. 0.]]
# [07-15 21:07:11][INFO] i= 2 x: [[ 6. 12.]]
# [07-15 21:07:11][INFO] i= 3 x: [[-6. 12.]]
# [07-15 21:07:11][INFO] i= 4 x: [[ -6. -12.]]
# [07-15 21:07:11][INFO] i= 5 x: [[ 18. -12.]]
# [07-15 21:07:11][INFO] i= 6 x: [[18. 36.]]
# [07-15 21:07:11][INFO] i= 7 x: [[-30.  36.]]
# [07-15 21:07:11][INFO] i= 8 x: [[-30. -60.]]
# [07-15 21:07:11][INFO] i= 9 x: [[ 66. -60.]]
# [07-15 21:07:11][INFO] i= 10 x: [[ 66. 132.]]
# [07-15 21:07:11][INFO] i= 11 x: [[-126.  132.]]
# [07-15 21:07:11][INFO] i= 12 x: [[-126. -252.]]
# [07-15 21:07:11][INFO] i= 13 x: [[ 258. -252.]]
# [07-15 21:07:11][INFO] i= 14 x: [[258. 516.]]
# [07-15 21:07:11][INFO] i= 15 x: [[-510.  516.]]
# [07-15 21:07:11][INFO] i= 16 x: [[ -510. -1020.]]
# [07-15 21:07:11][INFO] i= 17 x: [[ 1026. -1020.]]
# [07-15 21:07:11][INFO] i= 18 x: [[1026. 2052.]]
# [07-15 21:07:11][INFO] i= 19 x: [[-2046.  2052.]]
# [07-15 21:07:11][INFO] i= 20 x: [[-2046. -4092.]]
# [07-15 21:07:11][INFO] i= 21 x: [[ 4098. -4092.]]
# [07-15 21:07:11][INFO] i= 22 x: [[4098. 8196.]]
# [07-15 21:07:11][INFO] i= 23 x: [[-8190.  8196.]]
# [07-15 21:07:11][INFO] i= 24 x: [[ -8190. -16380.]]
# [07-15 21:07:11][INFO] i= 25 x: [[ 16386. -16380.]]
# [07-15 21:07:11][INFO] i= 26 x: [[16386. 32772.]]
# [07-15 21:07:11][INFO] i= 27 x: [[-32766.  32772.]]
# [07-15 21:07:11][INFO] i= 28 x: [[-32766. -65532.]]
# [07-15 21:07:11][INFO] i= 29 x: [[ 65538. -65532.]]
# [07-15 21:07:11][INFO] i= 30 x: [[ 65538. 131076.]]
# [07-15 21:07:11][INFO] i= 31 x: [[-131070.  131076.]]
